# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('../datasets/fridge_price_predictor.csv')
data.head()
# Out:
#        Brand   Model  Capacity Energy Rating          Type  \
# 0  Panasonic  Model0     369.0           A++           NaN
# 1         GE  Model1     619.0             A  Side-by-Side
# 2         GE  Model2     309.0             A   Single Door
# 3         LG  Model3     662.0             B  Side-by-Side
# 4      Bosch  Model4     533.0             B   Double Door
#
#              Features  Color         Material  Warranty Period  \
# 0                 NaN    NaN  Stainless Steel              5.0
# 1  Smart Connectivity  White            Glass              8.0
# 2       Ice Dispenser  Black  Stainless Steel              7.0
# 3       Ice Dispenser   Gray          Plastic              8.0
# 4     Water Dispenser   Gray          Plastic              NaN
#
#   Country of Manufacture   Price  Random Numeric Feature 1  \
# 0                Germany  1231.0                    3984.0
# 1                Germany   267.0                    3155.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Brand                          20000 non-null  object
#  1   Model                          19000 non-null  object
#  2   Capacity                       19012 non-null  float64
#  3   Energy Rating                  19000 non-null  object
#  4   Type                           19000 non-null  object
#  5   Features                       14226 non-null  object
#  6   Color                          19000 non-null  object
#  7   Material                       19000 non-null  object
#  8   Warranty Period                19000 non-null  float64
#  9   Country of Manufacture         19000 non-null  object
#  10  Price                          19000 non-null  float64
#  11  Random Numeric Feature 1       19000 non-null  float64
# ...

# %%
data.shape
# Out:
# (20000, 14)

# %%
data.drop(['Random Numeric Feature 1', 'Random Text Feature 2', 'Irrelevant Category Feature 3', 'Model'], axis=1, inplace = True)

# %%
data.head()
# Out:
#        Brand  Capacity Energy Rating          Type            Features  Color  \
# 0  Panasonic     369.0           A++           NaN                 NaN    NaN
# 1         GE     619.0             A  Side-by-Side  Smart Connectivity  White
# 2         GE     309.0             A   Single Door       Ice Dispenser  Black
# 3         LG     662.0             B  Side-by-Side       Ice Dispenser   Gray
# 4      Bosch     533.0             B   Double Door     Water Dispenser   Gray
#
#           Material  Warranty Period Country of Manufacture   Price
# 0  Stainless Steel              5.0                Germany  1231.0
# 1            Glass              8.0                Germany   267.0
# 2  Stainless Steel              7.0                  India   477.0
# 3          Plastic              8.0                  India     NaN
# 4          Plastic              NaN                  India   993.0

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Brand                        0
# Capacity                   988
# Energy Rating             1000
# Type                      1000
# Features                  5774
# Color                     1000
# Material                  1000
# Warranty Period           1000
# Country of Manufacture    1000
# Price                     1000
# dtype: int64

# %%
data['Warranty Period'].fillna(0.0, inplace=True)
# Out:
# C:\Users\RAYANEH INS\AppData\Local\Temp\ipykernel_19444\4026635784.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Warranty Period'].fillna(0.0, inplace=True)

# %%
data.head()
# Out:
#        Brand  Capacity Energy Rating          Type            Features  Color  \
# 0  Panasonic     369.0           A++           NaN                 NaN    NaN
# 1         GE     619.0             A  Side-by-Side  Smart Connectivity  White
# 2         GE     309.0             A   Single Door       Ice Dispenser  Black
# 3         LG     662.0             B  Side-by-Side       Ice Dispenser   Gray
# 4      Bosch     533.0             B   Double Door     Water Dispenser   Gray
#
#           Material  Warranty Period Country of Manufacture   Price
# 0  Stainless Steel              5.0                Germany  1231.0
# 1            Glass              8.0                Germany   267.0
# 2  Stainless Steel              7.0                  India   477.0
# 3          Plastic              8.0                  India     NaN
# 4          Plastic              0.0                  India   993.0

# %%
data.isnull().sum()
# Out:
# Brand                        0
# Capacity                   988
# Energy Rating             1000
# Type                      1000
# Features                  5774
# Color                     1000
# Material                  1000
# Warranty Period              0
# Country of Manufacture    1000
# Price                     1000
# dtype: int64

# %%
data.dropna(inplace= True)

# %%
data.isnull().sum()
# Out:
# Brand                     0
# Capacity                  0
# Energy Rating             0
# Type                      0
# Features                  0
# Color                     0
# Material                  0
# Warranty Period           0
# Country of Manufacture    0
# Price                     0
# dtype: int64

# %%
input = data.drop('Price', axis=1)

# %%
input.head()
# Out:
#    Brand  Capacity Energy Rating          Type            Features   Color  \
# 1     GE     619.0             A  Side-by-Side  Smart Connectivity   White
# 2     GE     309.0             A   Single Door       Ice Dispenser   Black
# 4  Bosch     533.0             B   Double Door     Water Dispenser    Gray
# 5     GE     371.0           A++   Single Door  Smart Connectivity  Silver
# 6     GE     288.0             B   Double Door  Smart Connectivity   White
#
#           Material  Warranty Period Country of Manufacture
# 1            Glass              8.0                Germany
# 2  Stainless Steel              7.0                  India
# 4          Plastic              0.0                  India
# 5            Glass              4.0                Germany
# 6            Glass              6.0                    USA

# %%
target = data['Price']
target
# Out:
# 1         267.0
# 2         477.0
# 4         993.0
# 5         462.0
# 6        1906.0
#           ...
# 19988     432.0
# 19989     881.0
# 19991     399.0
# 19996     870.0
# 19999    1573.0
# Name: Price, Length: 9913, dtype: float64

# %%
input['Brand'].unique()
# Out:
# array(['GE', 'Bosch', 'LG', 'Haier', 'Panasonic', 'Siemens', 'Frigidaire',
#        'Electrolux', 'Whirlpool', 'Samsung', 'Br@ndX'], dtype=object)

# %%
brand = LabelEncoder()
input['brand'] = brand.fit_transform(input['Brand'])

# %%
EnergyRating = LabelEncoder()
input['EnergyRating'] = EnergyRating.fit_transform(input['Energy Rating'])

# %%
input['Type'].unique()
# Out:
# array(['Side-by-Side', 'Single Door', 'Double Door'], dtype=object)

# %%
type = LabelEncoder()
input['type'] = type.fit_transform(input['Type'])

# %%
input['Features'].unique()
# Out:
# array(['Smart Connectivity', 'Ice Dispenser', 'Water Dispenser'],
#       dtype=object)

# %%
features = LabelEncoder()
input['features'] = features.fit_transform(input['Features'])

# %%
data.Color.unique()
# Out:
# array(['White', 'Black', 'Gray', 'Silver'], dtype=object)

# %%
color = LabelEncoder()
input['color'] = color.fit_transform(input['Color'])

# %%
input['Material'].unique()
# Out:
# array(['Glass', 'Stainless Steel', 'Plastic'], dtype=object)

# %%
material = LabelEncoder()
input['material'] = material.fit_transform(input['Material'])

# %%
input['Country of Manufacture'].unique()
# Out:
# array(['Germany', 'India', 'USA', 'China'], dtype=object)

# %%
country = LabelEncoder()
input['country'] = material.fit_transform(input['Country of Manufacture'])

# %%
input.head()
# Out:
#    Brand  Capacity Energy Rating          Type            Features   Color  \
# 1     GE     619.0             A  Side-by-Side  Smart Connectivity   White
# 2     GE     309.0             A   Single Door       Ice Dispenser   Black
# 4  Bosch     533.0             B   Double Door     Water Dispenser    Gray
# 5     GE     371.0           A++   Single Door  Smart Connectivity  Silver
# 6     GE     288.0             B   Double Door  Smart Connectivity   White
#
#           Material  Warranty Period Country of Manufacture  brand  \
# 1            Glass              8.0                Germany      4
# 2  Stainless Steel              7.0                  India      4
# 4          Plastic              0.0                  India      0
# 5            Glass              4.0                Germany      4
# 6            Glass              6.0                    USA      4
#
#    EnergyRating  type  features  color  material  country
# 1             0     1         1      3         0        1
# ...

# %%
input.drop(['Brand', 'Energy Rating', 'Type', 'Features', 'Color', 'Material', 'Country of Manufacture'], axis= 1, inplace= True)

# %%
input.head()
# Out:
#    Capacity  Warranty Period  brand  EnergyRating  type  features  color  \
# 1     619.0              8.0      4             0     1         1      3
# 2     309.0              7.0      4             0     2         0      0
# 4     533.0              0.0      0             3     0         2      1
# 5     371.0              4.0      4             2     2         1      2
# 6     288.0              6.0      4             3     0         1      3
#
#    material  country
# 1         0        1
# 2         2        2
# 4         1        2
# 5         0        1
# 6         0        3

# %%
scaler = StandardScaler()
scaler.fit(input)
x_scaled = scaler.transform(input)

# %%
x_scaled
# Out:
# array([[ 0.83550044,  1.17692453, -0.45297144, ...,  1.32014858,
#         -1.21048612, -0.42382003],
#        [-0.66564546,  0.81248343, -0.45297144, ..., -1.36098907,
#          1.25449928,  0.46085631],
#        [ 0.41905351, -1.73860425, -1.76659857, ..., -0.46727652,
#          0.02200658,  0.46085631],
#        ...,
#        [-1.52275135, -1.00972205,  0.20384212, ..., -0.46727652,
#         -1.21048612,  1.34553265],
#        [-0.16687763, -1.37416315,  1.18906246, ..., -1.36098907,
#          1.25449928, -1.30849637],
#        [ 0.92750616,  0.44804233, -0.45297144, ..., -1.36098907,
#          1.25449928,  1.34553265]])

# %%
target = x_scaled

# %%
x_train , x_test, y_train, y_test= train_test_split(input, target, test_size= 0.2)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
model.predict([[533.0,	0.0,	0,	3,	0,	2,	1,	1,	2]])
# Out:
# c:\Users\RAYANEH INS\miniconda3\envs\my_env\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[ 0.41905351, -1.73860425, -1.76659857,  1.34503155, -1.23487516,
#          1.20741071, -0.46727652,  0.02200658,  0.46085631]])

# %%
model.score(x_test, y_test)*100
# Out:
# 100.0

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 5.167984138228925e-27
