# %%
import numpy as np
import pandas as pd
from sklearn import linear_model

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('datasets/hiring.csv')
df
# Out:
#   experience  test_score  interview_score  salary
# 0        NaN         8.0                9   50000
# 1        NaN         8.0                6   45000
# 2       five         6.0                7   60000
# 3        two        10.0               10   65000
# 4      seven         9.0                6   70000
# 5      three         7.0               10   62000
# 6        ten         NaN                7   72000
# 7     eleven         7.0                8   80000

# %%
df.experience = df.experience.fillna('zero').astype('str')
df
# Out:
#   experience  test_score  interview_score  salary
# 0       zero         8.0                9   50000
# 1       zero         8.0                6   45000
# 2       five         6.0                7   60000
# 3        two        10.0               10   65000
# 4      seven         9.0                6   70000
# 5      three         7.0               10   62000
# 6        ten         NaN                7   72000
# 7     eleven         7.0                8   80000

# %%
df.test_score = df.test_score.fillna(df.test_score.median())
df
# Out:
#   experience  test_score  interview_score  salary
# 0       zero         8.0                9   50000
# 1       zero         8.0                6   45000
# 2       five         6.0                7   60000
# 3        two        10.0               10   65000
# 4      seven         9.0                6   70000
# 5      three         7.0               10   62000
# 6        ten         8.0                7   72000
# 7     eleven         7.0                8   80000

# %%
df.isnull().sum()
# Out:
# experience         0
# test_score         0
# interview_score    0
# salary             0
# dtype: int64

# %%
pip install word2number
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -r requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
from word2number import w2n

# %%
df.experience= df.experience.apply(w2n.word_to_num)
df
# Out:
#    experience  test_score  interview_score  salary
# 0           0         8.0                9   50000
# 1           0         8.0                6   45000
# 2           5         6.0                7   60000
# 3           2        10.0               10   65000
# 4           7         9.0                6   70000
# 5           3         7.0               10   62000
# 6          10         8.0                7   72000
# 7          11         7.0                8   80000

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['experience', 'test_score', 'interview_score']], df.salary)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([2812.95487627, 1845.70596798, 2205.24017467])

# %%
reg.intercept_
# Out:
# 17737.263464337688

# %%
reg.predict([[2, 9, 6]])
# Out:
# array([53205.96797671])

# %%
reg.predict([[12, 10, 10]])
# Out:
# array([92002.18340611])

# %% [markdown]
# # Save

# %% [markdown]
# # pickel

# %%
import pickle

# %%
with open('pickle_LinMultiVar_Prac', 'wb') as f:
    pickle.dump(reg, f)

# %%
with open('pickle_LinMultiVar_Prac', 'rb') as f:
    mp = pickle.load(f)

# %%
mp.predict([[12, 10, 10]])
# Out:
# array([92002.18340611])

# %% [markdown]
# # joblib

# %%
import joblib

# %%
joblib.dump( reg,'joblib_LinMultiVar_Prac')
# Out:
# ['joblib_LinMultiVar_Prac']

# %%
mj = joblib.load('joblib_LinMultiVar_Prac')

# %%
mj.predict([[10, 10, 2]])
# Out:
# array([68734.35225619])
