# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('datasets/realest.csv')
data.head()
# Out:
#    Price  Bedroom   Space  Room   Lot     Tax  Bathroom  Garage  Condition
# 0   53.0      2.0   967.0   5.0  39.0   652.0       1.5     0.0        0.0
# 1   55.0      2.0   815.0   5.0  33.0  1000.0       1.0     2.0        1.0
# 2   56.0      3.0   900.0   5.0  35.0   897.0       1.5     1.0        0.0
# 3   58.0      3.0  1007.0   6.0  24.0   964.0       1.5     2.0        0.0
# 4   64.0      3.0  1100.0   7.0  50.0  1099.0       1.5     1.5        0.0

# %%
data.tail()
# Out:
#      Price  Bedroom  Space  Room   Lot    Tax  Bathroom  Garage  Condition
# 152   44.0      3.0  820.0   5.0  27.0    NaN       1.0     0.0        1.0
# 153   43.0      2.0  593.0   4.0  30.0  465.0       2.0     1.0        0.0
# 154   53.0      3.0  716.0   6.0  30.0  585.0       1.0     2.0        1.0
# 155   62.0      4.0  951.0   7.0  30.0  895.0       2.0     1.0        0.0
# 156    NaN      NaN    NaN   NaN   NaN    NaN       NaN     NaN        NaN

# %%
data.isnull().sum()
# Out:
# Price         1
# Bedroom       1
# Space        11
# Room          1
# Lot          11
# Tax          10
# Bathroom      1
# Garage        1
# Condition     1
# dtype: int64

# %%
percent = (data.isnull().sum()/len(data))*100
percent
# Out:
# Price        0.636943
# Bedroom      0.636943
# Space        7.006369
# Room         0.636943
# Lot          7.006369
# Tax          6.369427
# Bathroom     0.636943
# Garage       0.636943
# Condition    0.636943
# dtype: float64

# %%
data[data['Price'].isna()]
# Out:
#      Price  Bedroom  Space  Room  Lot  Tax  Bathroom  Garage  Condition
# 156    NaN      NaN    NaN   NaN  NaN  NaN       NaN     NaN        NaN

# %%
data = data.drop(data[data['Price'].isna()].index)

# %%
data.tail()
# Out:
#      Price  Bedroom  Space  Room   Lot    Tax  Bathroom  Garage  Condition
# 151   42.0      3.0  585.0   5.0  50.0  713.0       1.0     0.0        0.0
# 152   44.0      3.0  820.0   5.0  27.0    NaN       1.0     0.0        1.0
# 153   43.0      2.0  593.0   4.0  30.0  465.0       2.0     1.0        0.0
# 154   53.0      3.0  716.0   6.0  30.0  585.0       1.0     2.0        1.0
# 155   62.0      4.0  951.0   7.0  30.0  895.0       2.0     1.0        0.0

# %%
data.describe()
# Out:
#             Price     Bedroom        Space        Room         Lot  \
# count  156.000000  156.000000   146.000000  156.000000  146.000000
# mean    56.474359    3.166667  1097.246575    6.500000   32.808219
# std     12.875307    1.348037   462.540698    1.675247    8.457859
# min     32.000000    1.000000   539.000000    4.000000   24.000000
# 25%     46.000000    2.000000   805.250000    5.000000   25.000000
# 50%     55.000000    3.000000   965.500000    6.000000   30.000000
# 75%     65.000000    4.000000  1220.500000    7.000000   37.000000
# max     90.000000    8.000000  2295.000000   12.000000   50.000000
#
#                Tax    Bathroom      Garage   Condition
# count   147.000000  156.000000  156.000000  156.000000
# mean    911.707483    1.480769    0.846154    0.230769
# std     443.263430    0.529408    0.808454    0.422682
# min     418.000000    1.000000    0.000000    0.000000
# 25%     652.500000    1.000000    0.000000    0.000000
# ...

# %%
data.isnull().sum()
# Out:
# Price         0
# Bedroom       0
# Space        10
# Room          0
# Lot          10
# Tax           9
# Bathroom      0
# Garage        0
# Condition     0
# dtype: int64

# %%
percent = (data.isnull().sum()/len(data))*100
percent
# Out:
# Price        0.000000
# Bedroom      0.000000
# Space        6.410256
# Room         0.000000
# Lot          6.410256
# Tax          5.769231
# Bathroom     0.000000
# Garage       0.000000
# Condition    0.000000
# dtype: float64

# %%
data[data['Space'].isnull()]
# Out:
#      Price  Bedroom  Space  Room   Lot     Tax  Bathroom  Garage  Condition
# 49    45.0      2.0    NaN   4.0  30.0   470.0       2.0     1.0        0.0
# 52    50.0      2.0    NaN   5.0  39.0   687.0       1.5     0.0        0.0
# 68    65.0      2.0    NaN   7.0  30.0   719.0       2.0     0.0        1.0
# 75    43.0      2.0    NaN   4.0  30.0   425.0       2.0     1.0        0.0
# 85    71.0      3.0    NaN   6.0  29.0  2687.0       1.0     2.0        0.0
# 95    61.0      4.0    NaN   8.0  37.0   581.0       2.0     2.0        0.0
# 112   70.0      5.0    NaN   8.0  33.0   768.0       1.5     1.5        0.0
# 129   63.0      3.0    NaN   7.0  30.0   843.0       2.0     1.0        0.0
# 142   45.0      4.0    NaN   6.0  25.0   649.0       1.0     0.0        0.0
# 147   66.0      4.0    NaN   8.0  37.0   565.0       2.0     2.0        0.0

# %%
data[data['Lot'].isnull()]
# Out:
#      Price  Bedroom   Space  Room  Lot     Tax  Bathroom  Garage  Condition
# 6     49.0      5.0  1400.0   8.0  NaN   678.0       1.0     1.0        1.0
# 8     72.0      4.0  1290.0   8.0  NaN   800.0       1.5     1.5        0.0
# 32    49.0      4.0  1408.0   8.0  NaN   650.0       1.0     1.0        1.0
# 73    44.0      3.0   579.0   5.0  NaN   753.0       1.0     0.0        0.0
# 127   44.0      2.0   705.0   4.0  NaN     NaN       2.0     1.0        0.0
# 128   50.0      2.0   634.0   6.0  NaN   536.0       1.0     2.0        1.0
# 130   49.0      2.0  1049.0   5.0  NaN   710.0       1.5     0.0        0.0
# 134   67.0      2.0  1122.0   7.0  NaN  1131.0       1.5     1.5        0.0
# 136   48.0      4.0  1424.0   8.0  NaN   621.0       1.0     1.0        1.0
# 148   69.0      1.0   957.0   5.0  NaN  1287.0       1.0     1.0        0.0

# %%
data[data['Tax'].isnull()]
# Out:
#      Price  Bedroom   Space  Room   Lot  Tax  Bathroom  Garage  Condition
# 17    64.0      4.0  1226.0   8.0  37.0  NaN       2.0     2.0        0.0
# 21    43.0      3.0   596.0   5.0  50.0  NaN       1.0     0.0        0.0
# 56    65.0      2.0  1145.0   7.0  50.0  NaN       1.5     1.5        0.0
# 79    52.0      2.0   855.0   5.0  33.0  NaN       1.0     2.0        1.0
# 121   68.0      4.0  1274.0   8.0  37.0  NaN       2.0     2.0        0.0
# 127   44.0      2.0   705.0   4.0   NaN  NaN       2.0     1.0        0.0
# 143   52.0      5.0  1074.0   7.0  30.0  NaN       1.5     0.0        0.0
# 150   42.0      2.0   639.0   6.0  25.0  NaN       1.0     0.0        0.0
# 152   44.0      3.0   820.0   5.0  27.0  NaN       1.0     0.0        1.0

# %%
sns.heatmap(data.corr(), annot=True)
# Out:
# <Axes: >

# %%
plt.scatter(data['Price'], data['Lot'])
plt.xlabel('price')
plt.ylabel('Lot')
# Out:
# Text(0, 0.5, 'Lot')

# %%
plt.scatter(data['Price'], data['Space'])
plt.xlabel('price')
plt.ylabel('Space')
# Out:
# Text(0, 0.5, 'Space')

# %%
plt.scatter(data['Price'], data['Tax'])
plt.xlabel('price')
plt.ylabel('Tax')
# Out:
# Text(0, 0.5, 'Tax')

# %%
data['Tax'].mean()
# Out:
# 911.7074829931972

# %%
data['Tax'] = data['Tax'].fillna(data['Tax'].mean())

# %%
data['Tax'].isnull().sum()
# Out:
# 0

# %%
data['Lot'] = data['Lot'].fillna(data['Lot'].mean())

# %%
data['Lot'].isnull().sum()
# Out:
# 0

# %%
data['Space'] = data['Space'].fillna(data['Space'].mean())

# %%
data['Space'].isnull().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Price        0
# Bedroom      0
# Space        0
# Room         0
# Lot          0
# Tax          0
# Bathroom     0
# Garage       0
# Condition    0
# dtype: int64

# %%
percent = (data.isnull().sum()/len(data))*100
percent
# Out:
# Price        0.0
# Bedroom      0.0
# Space        0.0
# Room         0.0
# Lot          0.0
# Tax          0.0
# Bathroom     0.0
# Garage       0.0
# Condition    0.0
# dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix

# %%
X = data.drop(['Price'], axis =1)
y = data['Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([59.32718529, 56.79786474, 59.95069083, 80.48460203, 80.73751414,
#        61.6986382 , 63.18475947, 58.08855891, 65.87211492, 59.74663017,
#        80.64770403, 45.10447113, 63.05502227, 42.96215419, 59.97162591,
#        38.71930609, 62.55666657, 49.46214661, 55.07196956, 76.467595  ,
#        40.95833498, 77.86182351, 66.53369617, 77.29388903, 43.76246583,
#        66.30694105, 47.85944005, 52.93406307, 55.20711987, 44.61871558,
#        44.31377111, 46.97956278])

# %%
model.predict([[2.0, 593.0, 4.0, 30.0, 465.0, 2.0, 1.0, 0.0]])  ## y_test = 43
# Out:
# array([48.80850368])

# %%
model.predict([[2.0, 815.0, 5.0, 33.0, 1000.0, 1.0, 2.0, 1.0]])   ### y_test = 55.0
# Out:
# array([58.46567083])

# %%
model.score(X_test, y_test)* 100
# Out:
# 71.71416614591574
